# %%
import pandas as pd
import datetime as dt
import yfinance as yf

# %%
sensex_index = ['^BSESN']

# %%
end_date = dt.datetime.now()
end_date
# Out:
# datetime.datetime(2025, 11, 25, 11, 11, 47, 846533)

# %%
start_date = end_date - dt.timedelta(days=365*10)
start_date
# Out:
# datetime.datetime(2015, 11, 28, 11, 11, 47, 846533)

# %%
df = yf.download(sensex_index,start=start_date,end=end_date)
# Out:
# C:\Users\vinay\AppData\Local\Temp\ipykernel_12304\2294085569.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(sensex_index,start=start_date,end=end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
# Price              Close          High           Low          Open Volume
# Ticker            ^BSESN        ^BSESN        ^BSESN        ^BSESN ^BSESN
# Date
# 2015-11-30  26145.669922  26231.060547  26089.130859  26142.529297   8300
# 2015-12-01  26169.410156  26246.019531  26121.519531  26201.269531  11000
# 2015-12-02  26117.849609  26256.419922  26041.679688  26239.390625  10100
# 2015-12-03  25886.619141  26123.859375  25857.349609  26123.859375   9500
# 2015-12-04  25638.109375  25810.060547  25623.710938  25810.060547  10500

# %%
import pandas as pd
import yfinance as yf
from datetime import datetime, timedelta
import requests

# ------------------------------------------------
# 1. Fetch SENSEX Constituents (403 FIX APPLIED)
# ------------------------------------------------

url = "https://en.wikipedia.org/wiki/List_of_BSE_SENSEX_companies"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

response = requests.get(url, headers=headers)

# Parse HTML manually with pandas
tables = pd.read_html(response.text)

sensex_constituents = tables[0]

# Add .BO suffix for BSE Yahoo Finance
sensex_constituents['YahooSymbol'] = sensex_constituents['Ticker'].astype(str) + ".BO"

sensex_constituents.to_csv('sensex_constituents.csv', index=False)
print("Saved → sensex_constituents.csv")

# ------------------------------------------------
# 2. Download 10 years of daily Adj Close prices
# ------------------------------------------------

start_date = (datetime.now() - timedelta(days=10*365)).strftime('%Y-%m-%d')

print("\nFetching 10 years of daily data...\n")
dfs = []

for symbol in sensex_constituents['YahooSymbol']:
    try:
        print(f"Downloading → {symbol}")
        df = yf.download(symbol, start=start_date)
        df = df[['Close']]
        df.columns = [symbol]
        dfs.append(df)
    except Exception as e:
        print(f"Failed → {symbol}, Reason: {e}")

sensex_data = pd.concat(dfs, axis=1)
sensex_data.to_csv("sensex_data.csv")
print("\nSaved → sensex_data.csv")

# ------------------------------------------------
# 3. Load and forward-fill missing data
# ------------------------------------------------

df = pd.read_csv("sensex_data.csv", index_col=0)
df_filled = df.ffill()

print("\nPreview:")
print(df_filled.head())
# Out:
# C:\Users\vinay\AppData\Local\Temp\ipykernel_12304\1733047485.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(response.text)
# C:\Users\vinay\AppData\Local\Temp\ipykernel_12304\1733047485.py:41: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date)
# Saved → sensex_constituents.csv
#
# Fetching 10 years of daily data...
#
# ...
# [*********************100%***********************]  1 of 1 completed
# C:\Users\vinay\AppData\Local\Temp\ipykernel_12304\1733047485.py:41: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start_date)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['500820.BO']: YFTzMissingError('possibly delisted; no timezone found')
# ...

# %%
daily_returns = df_filled.pct_change()
daily_returns.head()
# Out:
# C:\Users\vinay\AppData\Local\Temp\ipykernel_12304\252386237.py:1: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   daily_returns = df_filled.pct_change()
#             532921.BO  500820.BO  532215.BO  500034.BO  532978.BO  500049.BO  \
# Date
# 2015-11-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2015-12-01  -0.016965        NaN        NaN   0.015617   0.025812        NaN
# 2015-12-02  -0.006069        NaN        NaN  -0.004246   0.026446        NaN
# 2015-12-03  -0.010303        NaN        NaN  -0.005091  -0.004952        NaN
# 2015-12-04  -0.015038        NaN        NaN  -0.015801  -0.010052        NaN
#
#             532454.BO  543320.BO  532281.BO  500180.BO  ...  500325.BO  \
# Date                                                    ...
# ...

# %%
biggest_losers = daily_returns.apply(lambda day: day.nsmallest(10).index, axis=1)
biggest_losers.head()
# Out:
# Date
# 2015-11-30    Index(['532921.BO', '500820.BO', '532215.BO', ...
# 2015-12-01    Index(['532921.BO', '500209.BO', '500510.BO', ...
# 2015-12-02    Index(['500112.BO', '500209.BO', '500510.BO', ...
# 2015-12-03    Index(['500112.BO', '500696.BO', '500520.BO', ...
# 2015-12-04    Index(['500520.BO', '500034.BO', '532921.BO', ...
# dtype: object

# %%
# Initialize capital
capital = 10000

# Create a new dataframe to hold our capital at the end of each day
capital_over_time = pd.DataFrame(index=daily_returns.index)

# Loop over each trading day
for i in range(len(daily_returns.index) - 1):
    # Select the biggest losers for the current day
    losers = biggest_losers.iloc[i]
   
    # Get the closing prices for these stocks on the current and next trading days
    prices_today = df_filled.loc[daily_returns.index[i], losers]
    prices_tomorrow = df_filled.loc[daily_returns.index[i+1], losers]
   
    # Distribute our capital equally among these stocks and buy shares
    shares = (capital / 10) / prices_today
   
    # The next day, sell all shares at the closing price and update our capital
    capital = (shares * prices_tomorrow).sum()
   
    # Store our capital
    capital_over_time.loc[daily_returns.index[i+1], 'Capital'] = capital
capital_over_time.head()
# Out:
#                 Capital
# Date
# 2015-11-30          NaN
# 2015-12-01  3024.464152
# 2015-12-02  3016.858976
# 2015-12-03  2993.250210
# 2015-12-04  2965.581045

# %%
import numpy as np

# Calculate the return of our strategy
returns = capital_over_time['Capital'].pct_change().dropna()

# Calculate annualized return
annualized_return = (1 + returns.mean())**252 - 1

# Calculate annualized volatility
annualized_vol = returns.std() * np.sqrt(252)

# Calculate Sharpe ratio (assuming a risk-free rate of 0)
sharpe_ratio = annualized_return / annualized_vol

# Calculate max drawdown
rolling_max = capital_over_time['Capital'].cummax()
daily_drawdown = capital_over_time['Capital'] / rolling_max - 1.0
max_drawdown = daily_drawdown.cummin()

# Print out the calculated metrics
print('Annualized Return:', annualized_return)
print('Annualized Volatility:', annualized_vol)
print('Sharpe Ratio:', sharpe_ratio)
print('Max Drawdown:', max_drawdown.min())
# Out:
# Annualized Return: 0.2740070724610657
# Annualized Volatility: 0.19717489901598678
# Sharpe Ratio: 1.3896650832763933
# Max Drawdown: -0.41204347422335097

# %%
import yfinance as yf
import numpy as np

# Fetch daily adjusted close prices for Sensex (^BSESN)
sensex_data = yf.download('HDFCSENSEX.NS', start=daily_returns.index.min(), end=daily_returns.index.max())['Close']

# Daily returns
sensex_returns = sensex_data.pct_change().dropna()

# Annualized return
sensex_annual_return = (1 + sensex_returns.mean())**252 - 1

# Annualized volatility
sensex_annual_vol = sensex_returns.std() * np.sqrt(252)

# Sharpe ratio (risk-free rate = 0)
sensex_sharpe_ratio = sensex_annual_return / sensex_annual_vol
print("Sensex Sharpe Ratio:", sensex_sharpe_ratio)
sensex_sharpe_ratio = float(sensex_sharpe_ratio)

# Compare with your strategy
print("\nComparison:")
if sharpe_ratio > sensex_sharpe_ratio:
    print("🔥 Your mean reversion strategy outperformed the SENSEX!")
else:
    print("😬 Your strategy underperformed compared to the SENSEX benchmark.")
# Out:
# C:\Users\vinay\AppData\Local\Temp\ipykernel_12304\974784398.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   sensex_data = yf.download('HDFCSENSEX.NS', start=daily_returns.index.min(), end=daily_returns.index.max())['Close']
# [*********************100%***********************]  1 of 1 completed
# Sensex Sharpe Ratio: Ticker
# HDFCSENSEX.NS    0.83438
# dtype: float64
#
# Comparison:
# 🔥 Your mean reversion strategy outperformed the SENSEX!
# C:\Users\vinay\AppData\Local\Temp\ipykernel_12304\974784398.py:19: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   sensex_sharpe_ratio = float(sensex_sharpe_ratio)

# %%
performance_metrics = pd.DataFrame({
    'Strategy': ['Mean Reversion', 'SENSEX'],
    'Annualized Return': [annualized_return, sensex_annual_return],
    'Annualized Volatility': [annualized_vol, sensex_annual_vol],
    'Sharpe Ratio': [sharpe_ratio, sensex_sharpe_ratio]
})

print(performance_metrics)

if sharpe_ratio > sensex_sharpe_ratio:
    print("🔥 The mean reversion strategy had the higher risk-adjusted returns.")
else:
    print("📉 The SENSEX benchmark had the higher risk-adjusted returns.")
# Out:
#          Strategy                                Annualized Return  \
# 0  Mean Reversion                                         0.274007
# 1          SENSEX  Ticker
# HDFCSENSEX.NS    0.165351
# dtype: float64
#
#                              Annualized Volatility  Sharpe Ratio
# 0                                         0.197175      1.389665
# 1  Ticker
# HDFCSENSEX.NS    0.198173
# dtype: float64      0.834380
# 🔥 The mean reversion strategy had the higher risk-adjusted returns.

# %%
print(sensex_data.head())
print(sensex_data.tail())
print(sensex_data.shape)
# Out:
# Ticker            ^BSESN
# Date
# 2015-11-30  26145.669922
# 2015-12-01  26169.410156
# 2015-12-02  26117.849609
# 2015-12-03  25886.619141
# 2015-12-04  25638.109375
# Ticker            ^BSESN
# Date
# 2025-11-17  84950.953125
# 2025-11-18  84673.023438
# 2025-11-19  85186.468750
# 2025-11-20  85632.679688
# 2025-11-21  85231.921875
# (2458, 1)

# %%
sensex_prices = sensex_data.iloc[:, 0]  # Series with index=Date, name='^BSESN'
sensex_cumulative_returns = (sensex_prices.pct_change() + 1).cumprod()
sensex_portfolio_value = sensex_cumulative_returns * 10000  # still a Series now ✅

# %%
capital_over_time['Capital_Returns'] = capital_over_time['Capital'].pct_change() + 1
strategy_cumulative = capital_over_time['Capital_Returns'].cumprod()
strategy_portfolio_value = strategy_cumulative * 10000

# %%
# --- Plot ---
import plotly.graph_objects as go

fig = go.Figure()

# Strategy line
fig.add_trace(go.Scatter(
    x=strategy_portfolio_value.index,
    y=strategy_portfolio_value,
    mode='lines',
    name='Mean Reversion Strategy'
))

# Sensex line (FIXED INDEX)
fig.add_trace(go.Scatter(
    x=sensex_portfolio_value.index,
    y=sensex_portfolio_value,
    mode='lines',
    name='SENSEX ETF'
))

fig.update_layout(
    title="Growth of ₹10,000 Portfolio: Strategy vs SENSEX Benchmark",
    xaxis_title="Date",
    yaxis_title="Portfolio Value (₹)",
    legend_title="Strategy",
    height=600,
    width=900,
    font=dict(size=12)
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\vinay\Desktop\Can I Fly\Quantitative Finance\quant\Lib\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File c:\Users\vinay\Desktop\Can I Fly\Quantitative Finance\quant\Lib\site-packages\plotly\basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File c:\Users\vinay\Desktop\Can I Fly\Quantitative Finance\quant\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
# ...

# %%
import yfinance as yf
import numpy as np

# Fetch daily adjusted close prices for HDFC SENSEX ETF
sensex_data = yf.download('HDFCSENSEX.NS', start=daily_returns.index.min(), end=daily_returns.index.max())['Close']

# Daily returns
sensex_returns = sensex_data.pct_change().dropna()

# Annualized return
sensex_annual_return = (1 + sensex_returns.mean())**252 - 1

# Annualized volatility
sensex_annual_vol = sensex_returns.std() * np.sqrt(252)

# Sharpe ratio
sensex_sharpe_ratio = sensex_annual_return / sensex_annual_vol

# Convert Series -> float correctly
sensex_sharpe_ratio = sensex_sharpe_ratio.iloc[0]

print("Sensex Sharpe Ratio:", sensex_sharpe_ratio)

# Comparison
print("\nComparison:")
if sharpe_ratio > sensex_sharpe_ratio:
    print("🔥 Your mean reversion strategy outperformed the SENSEX!")
else:
    print("😬 Your strategy underperformed compared to the SENSEX benchmark.")
# Out:
# C:\Users\vinay\AppData\Local\Temp\ipykernel_12304\1584587274.py:5: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# [*********************100%***********************]  1 of 1 completed
# Sensex Sharpe Ratio: 0.8343804970752319
#
# Comparison:
# 🔥 Your mean reversion strategy outperformed the SENSEX!
